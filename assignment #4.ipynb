# %%
questions = [
    {
        "Q.NO":1,
        "question":"who was the first President of the Constitution Assembly of Pakistan? ",
        "options":["Liaquat Ali Khan","Moulvi Tameez-ud-Din","Quaid-e-Azam","Sardar Abdur Rab Nishtar"],
        "answer":"Quaid-e-Azam"
    
    },
    {
        "Q.NO":2,
        "question":"After how many years did Pakistan got its first constitution?" ,
        "options":["5 years","9 years","11 years","7 years"],
        "answer":"9 years"
    
    },
    {
        "Q.NO":3,
        "question":"What document was firstly drafted to give pace to constitution making process? " ,
        "options":["Independence Act","Representative Act","Objective Resolution","Pakistan Act"],
        "answer":"Objective Resolution"
    
    },
    
    {
        "Q.NO":4,
        "question":"When the Constituent Assembly passed the Objective Resolution? " ,
        "options":["15th August 1949","14th February 1949","9th June 1949","12th March 1949"],
        "answer":"12th March 1949"
    
    },    
    
    {
        "Q.NO":5,
        "question":"When first constitution of Pakistan was enforced? " ,
        "options":["25th December 1956","8th June 1956","23rd March 1956","14th August 1956"],
        "answer":"23rd March 1956"
    
    },    
    
    {
        "Q.NO":6,
        "question":"What was the official language declared in 1956 constitution? " ,
        "options":["Both Urdu & Bengali","Hindi","Bengali","Urdu"],
        "answer":"Both Urdu & Bengali"
    
    },    
    
    {
        "Q.NO":7,
        "question":"Oldest mountains of the world are present in india and youngest mountain of the world are present in ? " ,
        "options":["Pakistan","China","India","Burma"],
        "answer":"Pakistan"
    
    },    
    
    {
        "Q.NO":8,
        "question":"Name the range which separates Pakistan from Afghanistan? " ,
        "options":["Pmir","Hindu Kush","Karakoram","Himalayas"],
        "answer":"Hindu Kush"
    
    },    
    
    
     {
        "Q.NO":9,
        "question":"What is the height of Siachin Glacier ? " ,
        "options":["23,000 feet","25,000 feet","27,000 feet","20,000 feet"],
        "answer":"20,000 feet"
    
    },   
    
    
    {
        "Q.NO":10,
        "question":"The Salt range is situated between rivers soan and _____________? " ,
        "options":["Chenab","Kabul","Jhelum","Huro"],
        "answer":"Jhelum"
    
    }    
        
]


score = 0
for question in questions:
    data = str(question["Q.NO"]) + ": "+ question["question"] + "\n"+ question["options"][0] + "\n"+ question["options"][1] + "\n"+ question["options"][2] + "\n"+ question["options"][3]+"\n"
    answer =input (data)
    if answer == question["answer"]:
        score +=1
print ("Your Score Is : "+ str(score))

score = int(score)
a = score /10*100
print ("Percentage \t",a)

per = score
if per >= 7 and per <10:
    print ("Congratulation ! You Pass")
elif per >0 and per <7:
    print("Sorry You Loss")
else:
    print("Error")
# Out:
# 1: who was the first President of the Constitution Assembly of Pakistan?
# Liaquat Ali Khan
# Moulvi Tameez-ud-Din
# Quaid-e-Azam
# Sardar Abdur Rab Nishtar
# Quaid-e-Azam
# 2: After how many years did Pakistan got its first constitution?
# 5 years
# 9 years
# 11 years
# 7 years
# 11 years
# 3: What document was firstly drafted to give pace to constitution making process?
# Independence Act
# Representative Act
# Objective Resolution
# Pakistan Act
# Objective Resolution
# 4: When the Constituent Assembly passed the Objective Resolution?
# 15th August 1949
# 14th February 1949
# 9th June 1949
# 12th March 1949
# 9th June 1949
# 5: When first constitution of Pakistan was enforced?
# 25th December 1956
# 8th June 1956
# 23rd March 1956
# 14th August 1956
# 23rd March 1956
# 6: What was the official language declared in 1956 constitution?
# Both Urdu & Bengali
# Hindi
# Bengali
# Urdu
# Both Urdu & Bengali
# ...
